# %%
using JuMP, MosekTools, Gurobi
using SparseArrays, LinearAlgebra, Plots
using PowerModels, Ipopt
include("../src/CVXRS_OPF.jl")
# Out:
# Academic license - for non-commercial use only
# WARNING: redefining constant GRB_ENV
# sample_pf (generic function with 2 methods)

# %%
num_data=100#00

#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case3_lmbd.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case5_pjm.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case14_ieee.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case24_ieee_rts.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case30_as.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case30_fsr.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case30_ieee.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case39_epri.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case57_ieee.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case73_ieee_rts.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case89_pegase.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case118_ieee.m");
network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case162_ieee_dtc.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case179_goc.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case200_tamu.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case240_pserc.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case300_ieee.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case500_tamu.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case588_sdet.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case1354_pegase.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case1888_rte.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case1951_rte.m");
#network_data = PowerModels.parse_file("../../../pglib-opf-master/pglib_opf_case2000_tamu.m");

result_opf=run_opf(network_data, ACPPowerModel, with_optimizer(Ipopt.Optimizer,print_level=0))
println("Local search OPF objective solution: ",round(result_opf["objective"],digits=2))

## Initialize OPF
network_data=opf_initialization(network_data, 0.0)
#[network_data["gen"][i]["ptc_factor"]=Int(network_data["bus"][string(gen["gen_bus"])]["bus_type"]==3) for (i,gen) in network_data["gen"]]
[network_data["gen"][i]["ptc_factor"]=gen["gen_status"]*float((gen["pmax"]-gen["pmin"])>0) for (i,gen) in network_data["gen"]]

network_data=runpf(network_data)
test_runpf(network_data)
println("Initial OPF objective solution: ",round(network_data["cost"],digits=2))
violation_status, margin=check_violation(network_data)
# Out:
# [info | PowerModels]: removing 1 cost terms from generator 4: [1968.68, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 1: [2353.26, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 12: [1135.44, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 2: [3040.93, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 6: [611.172, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 11: [1523.45, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 5: [3849.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 7: [2293.42, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 8: [2974.78, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 10: [737.308, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 9: [2037.7, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 3: [1904.04, 0.0]
# Local search OPF objective solution: 108075.64
# Initial OPF objective solution: 108075.64
# (Dict("line"=>[],"qg"=>[],"pg"=>[],"angle"=>[],"vmag"=>[]), 0.1)

# %%
(Σ0,γ0)=network_data["uncertainty"]
Σ0=Σ0+1e-3*Matrix{Float64}(I,size(Σ0,1),size(Σ0,1))
network_data["uncertainty"]=(Σ0,gamma_req)
pl_sampled,data_gencost_bounded,violation_count_bounded,sample_violation_bounded=sample_pf(network_data,num_data,1)
count_bounded=violation_count_bounded
cost_worst_sampled=maximum(data_gencost_bounded)

(Σ0,γ0)=network_data["uncertainty"]
network_data["uncertainty"]=(Σ0,gamma_req/2)
pl_sampled,data_gencost_bounded,violation_count_normal,sample_violation_bounded=sample_pf(network_data,num_data,0)
count_normal=violation_count_normal

println("Violation probability (Bounded): ",count_bounded/num_data*100)
println("Violation probability (Normal): ",count_normal/num_data*100)
# Out:
# Violation probability (Bounded): 100.0
# Violation probability (Normal): 100.0

# %%
include("../src/CVXRS_OPF.jl")

gamma_req=0.01
max_iter_SCRS=1

(Σ0,γ0)=network_data["uncertainty"]
network_data["uncertainty"]=(Σ0,gamma_req)

network_data, result_cvxr=scrs(network_data, max_iter_SCRS,false);

println("Robust OPF objective solution: ",round(network_data["cost"],digits=2))
# Out:
# Academic license - for non-commercial use only
# WARNING: redefining constant GRB_ENV
# ┌ Warning: CVXRS was not optimal. (SLOW_PROGRESS)
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:698
# ┌ Warning: Vm out of range at bus 78/5: 1.009221 ≤ 1.009166 ≤ 1.010178
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 53/18: 0.985427 ≤ 0.985084 ≤ 0.985859
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 119/20: 1.007229 ≤ 1.007185 ≤ 1.007713
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 75/22: 1.032877 ≤ 1.032707 ≤ 1.032859
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 52/27: 1.013812 ≤ 1.013617 ≤ 1.013967
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 159/28: 0.952125 ≤ 0.952034 ≤ 0.9529
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 162/30: 0.985647 ≤ 0.985402 ≤ 0.986113
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 77/41: 1.000377 ≤ 1.000333 ≤ 1.001458
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 160/49: 0.953964 ≤ 0.953851 ≤ 0.954663
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 154/50: 0.957251 ≤ 0.957105 ≤ 0.957816
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 149/51: 1.001622 ≤ 1.001575 ≤ 1.001744
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 49/52: 0.970199 ≤ 0.970064 ≤ 0.970972
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 5/54: 1.057681 ≤ 1.05755 ≤ 1.057686
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 112/63: 1.047951 ≤ 1.047723 ≤ 1.047902
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 55/70: 0.984979 ≤ 0.984628 ≤ 0.985422
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: vv out of range at bus 55: 0.969531 ≤ 0.969493 ≤ 0.971663
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:721
# ┌ Warning: Vm out of range at bus 161/72: 0.987279 ≤ 0.987063 ≤ 0.987675
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 47/79: 0.972331 ≤ 0.972193 ≤ 0.973053
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 82/82: 0.987907 ≤ 0.987861 ≤ 0.988651
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 79/84: 1.018768 ≤ 1.018716 ≤ 1.019658
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 20/85: 0.967625 ≤ 0.967436 ≤ 0.968479
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 110/96: 1.044852 ≤ 1.044578 ≤ 1.044802
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 70/97: 1.002259 ≤ 1.002232 ≤ 1.002385
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 157/100: 0.967652 ≤ 0.967422 ≤ 0.968381
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 69/112: 1.008108 ≤ 1.008012 ≤ 1.009012
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 158/115: 0.953002 ≤ 0.952909 ≤ 0.953899
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 4/116: 1.022527 ≤ 1.022504 ≤ 1.023028
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 156/117: 0.961267 ≤ 0.961142 ≤ 0.961868
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 11/121: 0.99646 ≤ 0.996377 ≤ 0.997093
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 67/131: 0.990554 ≤ 0.990541 ≤ 0.991743
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 40/136: 0.990563 ≤ 0.990538 ≤ 0.991361
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 83/141: 0.990123 ≤ 0.990091 ≤ 0.990841
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 151/142: 0.990753 ≤ 0.990653 ≤ 0.991204
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 68/144: 1.001829 ≤ 1.001788 ≤ 1.002889
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 116/146: 1.022398 ≤ 1.022382 ≤ 1.022976
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: Vm out of range at bus 128/147: 1.038966 ≤ 1.038914 ≤ 1.039225
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:714
# ┌ Warning: g_vvcos out of range at line 168: -1.003957 ≤ -1.00397 ≤ -1.003975
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 159: -1.027875 ≤ -1.027886 ≤ -1.027888
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: vvcos out of range at line 228: 1.074109 ≤ 1.073917 ≤ 1.077197
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: g_vvcos out of range at line 227: -1.093361 ≤ -1.093375 ≤ -1.093378
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: vvcos out of range at line 223: 1.063101 ≤ 1.062997 ≤ 1.065477
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: g_vvcos out of range at line 88: -0.998553 ≤ -0.998565 ≤ -0.998567
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 250: -1.100132 ≤ -1.100143 ≤ -1.100137
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 77: -0.985357 ≤ -0.985367 ≤ -0.985368
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 230: -1.082178 ≤ -1.082192 ≤ -1.082195
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 253: -1.093261 ≤ -1.093274 ≤ -1.093276
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 175: -1.005877 ≤ -1.005888 ≤ -1.005884
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 112: -0.968125 ≤ -0.968135 ≤ -0.968135
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: vvcos out of range at line 137: 0.970243 ≤ 0.969935 ≤ 0.971787
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: g_vvcos out of range at line 137: -0.971394 ≤ -0.971407 ≤ -0.971412
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 55: -1.111322 ≤ -1.111332 ≤ -1.111334
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 17: -1.0986 ≤ -1.098612 ≤ -1.098609
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 172: -1.083367 ≤ -1.08338 ≤ -1.083381
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 20: -1.089791 ≤ -1.089803 ≤ -1.089805
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 252: -1.087167 ≤ -1.087177 ≤ -1.087167
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: vvcos out of range at line 177: 1.04222 ≤ 1.042107 ≤ 1.045098
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: vvcos out of range at line 19: 1.097152 ≤ 1.097034 ≤ 1.098212
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: g_vvcos out of range at line 276: -0.920873 ≤ -0.920884 ≤ -0.920887
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 21: -1.070979 ≤ -1.070991 ≤ -1.070993
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 45: -1.101035 ≤ -1.101046 ≤ -1.101041
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 181: -0.978651 ≤ -0.978664 ≤ -0.978668
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 105: -0.963253 ≤ -0.963265 ≤ -0.963267
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 92: -0.977985 ≤ -0.977995 ≤ -0.977997
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 208: -0.987542 ≤ -0.987554 ≤ -0.987556
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 224: -1.084898 ≤ -1.08491 ≤ -1.084908
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 117: -0.970255 ≤ -0.970267 ≤ -0.970267
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 255: -1.093116 ≤ -1.093127 ≤ -1.093117
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 178: -1.027161 ≤ -1.027173 ≤ -1.027176
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 176: -1.072013 ≤ -1.072026 ≤ -1.072028
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 225: -1.04321 ≤ -1.043221 ≤ -1.043212
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 195: -0.970485 ≤ -0.970496 ≤ -0.970498
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 161: -0.998015 ≤ -0.998028 ≤ -0.998032
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 142: -0.971078 ≤ -0.97109 ≤ -0.971093
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 219: -0.984298 ≤ -0.984309 ≤ -0.984311
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 110: -0.972296 ≤ -0.972307 ≤ -0.972309
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 269: -0.989809 ≤ -0.98982 ≤ -0.98982
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 165: -1.018577 ≤ -1.018588 ≤ -1.018591
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 231: -1.032851 ≤ -1.032864 ≤ -1.032868
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 173: -1.087566 ≤ -1.087579 ≤ -1.08758
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 284: -0.973525 ≤ -0.973538 ≤ -0.973542
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 233: -1.028592 ≤ -1.028605 ≤ -1.028609
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 15: -1.040418 ≤ -1.040431 ≤ -1.040434
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 61: -1.053379 ≤ -1.05339 ≤ -1.053393
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 67: -0.937535 ≤ -0.937547 ≤ -0.93755
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 46: -1.021813 ≤ -1.021823 ≤ -1.021824
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 248: -1.103268 ≤ -1.103281 ≤ -1.10328
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 147: -0.995805 ≤ -0.995815 ≤ -0.995817
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 76: -0.984033 ≤ -0.984044 ≤ -0.984047
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 180: -1.014673 ≤ -1.014686 ≤ -1.014689
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 135: -0.982644 ≤ -0.982655 ≤ -0.982654
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 109: -0.982843 ≤ -0.982856 ≤ -0.98286
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 217: -0.909152 ≤ -0.909163 ≤ -0.909163
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 51: -1.109829 ≤ -1.109839 ≤ -1.109841
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 111: -0.98121 ≤ -0.981222 ≤ -0.981223
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 93: -1.024547 ≤ -1.024557 ≤ -1.024559
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 265: -1.031477 ≤ -1.031488 ≤ -1.031489
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 234: -1.03192 ≤ -1.031932 ≤ -1.031934
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 237: -1.084379 ≤ -1.084393 ≤ -1.084397
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 164: -1.008832 ≤ -1.008844 ≤ -1.008847
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 71: -0.998242 ≤ -0.998253 ≤ -0.998256
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 245: -1.075108 ≤ -1.07512 ≤ -1.07512
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 268: -1.001072 ≤ -1.001085 ≤ -1.001089
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 6: -1.082095 ≤ -1.082108 ≤ -1.082111
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 125: -0.932752 ≤ -0.932762 ≤ -0.932763
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 187: -0.950835 ≤ -0.950846 ≤ -0.950847
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 194: -0.953116 ≤ -0.953126 ≤ -0.953126
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 107: -0.97958 ≤ -0.979593 ≤ -0.979597
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 282: -0.908431 ≤ -0.908441 ≤ -0.908441
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 97: -0.99279 ≤ -0.992801 ≤ -0.992803
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 4: -1.120089 ≤ -1.120102 ≤ -1.120102
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 235: -1.024477 ≤ -1.02449 ≤ -1.024493
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 212: -0.972023 ≤ -0.972036 ≤ -0.972039
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: vvcos out of range at line 134: 1.028911 ≤ 1.028808 ≤ 1.030683
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:750
# ┌ Warning: g_vvcos out of range at line 133: -1.027666 ≤ -1.027676 ≤ -1.027674
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 148: -0.995803 ≤ -0.995815 ≤ -0.995817
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 118: -0.954884 ≤ -0.954895 ≤ -0.954897
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 246: -1.088406 ≤ -1.088418 ≤ -1.088417
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 199: -0.994806 ≤ -0.994818 ≤ -0.994819
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 116: -0.958672 ≤ -0.958683 ≤ -0.958684
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 18: -1.100026 ≤ -1.100038 ≤ -1.100033
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 132: -1.034788 ≤ -1.034798 ≤ -1.034797
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 29: -0.979586 ≤ -0.979597 ≤ -0.9796
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 78: -0.982356 ≤ -0.982367 ≤ -0.982368
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 74: -0.996178 ≤ -0.996189 ≤ -0.996192
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 236: -1.092747 ≤ -1.092758 ≤ -1.092758
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 28: -1.067837 ≤ -1.06785 ≤ -1.067851
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 121: -0.944377 ≤ -0.944389 ≤ -0.944394
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 163: -1.010458 ≤ -1.01047 ≤ -1.010473
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 166: -1.024454 ≤ -1.024466 ≤ -1.024468
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 44: -1.096847 ≤ -1.096858 ≤ -1.096853
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 169: -1.003957 ≤ -1.00397 ≤ -1.003975
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 94: -1.011543 ≤ -1.011555 ≤ -1.011558
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 73: -1.018737 ≤ -1.018748 ≤ -1.01875
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 104: -1.019609 ≤ -1.019621 ≤ -1.019625
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 238: -1.090804 ≤ -1.090818 ≤ -1.090822
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 70: -1.04212 ≤ -1.042132 ≤ -1.042135
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 222: -1.091381 ≤ -1.091392 ≤ -1.091392
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 158: -1.052936 ≤ -1.052947 ≤ -1.052946
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 271: -0.978114 ≤ -0.978127 ≤ -0.97813
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 277: -0.91381 ≤ -0.913821 ≤ -0.913823
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 16: -1.029029 ≤ -1.029042 ≤ -1.029046
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 72: -1.010534 ≤ -1.010545 ≤ -1.010548
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 36: -0.982465 ≤ -0.982476 ≤ -0.982478
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 232: -1.037664 ≤ -1.037676 ≤ -1.037678
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: g_vvcos out of range at line 153: -0.985019 ≤ -0.985031 ≤ -0.985033
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:754
# ┌ Warning: Qg violation at bus 114: -0.25 ≤ 0.33 ≤ 0.33
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:210
# ┌ Warning: Qg violation at bus 118: -0.44 ≤ 1.0 ≤ 1.0
# └ @ Main /Users/dc/Documents/Github/CVXRS_master/CVXRS_OPF/src/CVXRS_OPF.jl:210
# Iteration 1: 108965.87  109444.641   SLOW_PROGRESS    38.9716   0.0052
# Robust OPF objective solution: 108965.87

# %%
(Σ0,γ0)=network_data["uncertainty"]
network_data["uncertainty"]=(Σ0,gamma_req)
pl_sampled,data_gencost_bounded,violation_count_bounded,sample_violation_bounded=sample_pf(network_data,num_data,1)
count_bounded=violation_count_bounded
cost_worst_sampled=maximum(data_gencost_bounded)

(Σ0,γ0)=network_data["uncertainty"]
network_data["uncertainty"]=(Σ0,gamma_req/2)
pl_sampled,data_gencost_bounded,violation_count_normal,sample_violation_bounded=sample_pf(network_data,num_data,0)
count_normal=violation_count_normal

println("Violation probability (Bounded): ", count_bounded/num_data*100)
println("Violation probability (Normal): ", count_normal/num_data*100)
println("Solver Time: ", sum(result_cvxr["solver_time"]))
println("Solver Time (1 iter): ", result_cvxr["solver_time"][2])
# Out:
# Violation probability (Bounded): 70.0
# Violation probability (Normal): 77.0
# Solver Time: 23.386204957962036
# Solver Time (1 iter): 23.386204957962036
